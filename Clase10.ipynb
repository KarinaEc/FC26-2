# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def integral_h2(f,x):
    integral , h =0, x[1]-x[0]
    for i in range(len(x)-2):
        integral += f[i+1] + 24*f[i] + f[i-1]
    integral += 0.5*(17*f[0] + 7*f[1] + f[2] - f[3])
    integral += 0.5*(17*f[-1] + 7*f[-2] + f[-3] - f[-4])
    return integral*h/24

def Int_Riem(f,x):
    integral, h = 0 , x[1]-x[0]
    for i in range(len(x)-1):
        integral += f[i]
    return integral*h

def Int_Riem_d(f,x):
    integral, h = 0 , x[1]-x[0]
    for i in range(len(x)-1):
        integral += f[i+1]
    return integral*h

def integral_h2_impar(f,x):
    integral , h =0, x[1]-x[0]
    for i in range(1,len(x),2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    return integral*h/3

def integral_h2_par(f,x):
    integral , h =0, x[1]-x[0]
    for i in range(1,len(x),2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    return integral*h/3

def integral_h2_mejorado(f,x):
    if len(x)%2 == 0

# %%
x = np.linspace(0,np.pi, 11)
y = np.sin(x)
print('h =', x[1] - x[0])
print('Integral h2', integral_h2(y,x))
print('Integral Riem', Int_Riem(y,x))
print('Integral Riem', Int_Riem_d(y,x))
print('integral h2 mejorado', integral_h2_impar(y,x))
# Out:
# h = 0.3141592653589793
# Integral h2 2.065416743990714
# Integral Riem 1.9835235375094546
# Integral Riem 1.9835235375094546
# integral h2 mejorado 2.0001095173150043

# %%
x = np.linspace(0,np.pi, 100)
y = np.sin(x)
print('h =', x[1] - x[0])
print('Integral h2', integral_h2(y,x))
print('Integral Riem', Int_Riem(y,x))
print('Integral Riem', Int_Riem_d(y,x))
# Out:
# h = 0.03173325912716963
# Integral h2 2.1656040362481357
# Integral Riem 1.9998321638939924
# Integral Riem 1.9998321638939924
