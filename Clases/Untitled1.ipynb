# %%
import numpy as np

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\karin\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
a = [3,5,9,"Karina es ..."]
print(a[0], a[1],a[2], a[3])
print(a[-0], a[-1],a[-2], a[-3])
print(a[2],a[3][0])
print(a[3][3])
print(3*a)
# Out:
# 3 5 9 Karina es ...
# 3 Karina es ... 9 5
# 9 K
# i
# [3, 5, 9, 'Karina es ...', 3, 5, 9, 'Karina es ...', 3, 5, 9, 'Karina es ...']

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,np.pi,100)
y1 = np.tan(x)
y2 = np.sin(x)
y3 = np.cos(x)
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.title(r"Gráfica de $\tan (x)$")
plt.xlabel(r"$x$"),plt.ylabel(r"$y$")
plt.savefig("Grafica de Tan.pdf")
plt.show()

# %% [markdown]
# Campo electrico
#
# $$
# \vec{E} = \frac{1}{4 \pi \epsilon _0} \frac{q \bar{r} - \bar{r_q}}{|\bar{r} - \bar{r_q}|^2}
# $$

# %%
def E_q(r,r_q,q):
    d32 = ((r[0]-r_q[0])**2 + (r[1]-r_q[1])**2)**1.5
    return (q*(r[0]-r_q[0]))/d32 , (q*(r[1]-r_q[1]))/d32

# %%
x,y = np.linspace(-2,2) , np.linspace(-2,2)
XX,YY =np.meshgrid(x,y)
N = np.sqrt(XX**2 + YY**2)
plt.quiver(XX,YY,YY/N,-XX/N)
plt.streamplot(XX,YY,YY/N,-XX/N)
plt.gca().set_aspect("equal")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
r_q , q = [0,0],1
Ex,Ey = E_q([XX,YY],r_q,q)
plt.streamplot(XX,YY,Ex,Ey,density=2)
plt.plot(r_q[0],r_q[1], "o")
plt.gca().set_aspect("equal")
plt.show()

# %%
r_q , q =[0,1] , 1
Ex,Ey = E_q([XX,YY],r_q,q)
r_q_n , q_n = [0,-1] , -1
Ex_neg, Ey_neg = E_q([XX,YY], r_q_n,q_n)
Et_x = Ex + Ex_neg
Et_y = Ey + Ey_neg
plt.streamplot(XX,YY,Et_x,Et_y,density=2)
plt.plot(r_q[0],r_q[1],"o")
plt.gca().set_aspect("equal")
plt.show()
